# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merged = pd.read_csv('/Users/yukbuinnemtat/Desktop/30-07-2023 Instacart Basket Analysis/Prepared Data/orders_products_merged.csv')

# %%
df = ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 13)

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # TASK 4.8

# %% [markdown]
# ### 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Calculate the aggregated mean of "order_number" column grouped by "department_id" for the entire DataFrame

aggregated_mean = ords_prods_merged.groupby('department_id')['order_number'].mean()

# %%
aggregated_mean.head()
# Out:
# department_id
# 1    15.457687
# 2    17.277920
# 3    17.179756
# 4    17.811403
# 5    15.213779
# Name: order_number, dtype: float64

# %% [markdown]
# ### 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# #### Compared to the results obtained from the subset, there appear to be different means obtained from different departments with dorminant departments being department ID's of 4, 2, 3 (produce, other and bakery respectively), having means of around 18. Conversely, the departments with an ID of 1 and 5 (frozen and alcohol respectively), have means of around 16. Thus, departments with means of around 18 sell considerably more goods on average than those with means of around 16.
#
# #### The only similarity with respect to the subset result is that, both data have a produce as their highest selling goods compared to rest of the departments.

# %% [markdown]
# ### 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Create a new column "loyalty_flag" using transform and loc functions

ords_prods_merged['loyalty_flag'] = ords_prods_merged.groupby('user_id' )['order_number'].transform('max')

# %%
# Assign loyalty categories based on the condition

ords_prods_merged.loc[ords_prods_merged['loyalty_flag'] > 1, 'loyalty_flag'] = 'Loyal Customer'

# %%
# Assign loyalty categories based on the condition
1
ords_prods_merged.loc[ords_prods_merged['loyalty_flag'] == 1, 'loyalty_flag'] = 'Regular Customer'

# %%
# Assign loyalty categories based on the condition

ords_prods_merged.loc[ords_prods_merged['loyalty_flag'] == 0, 'loyalty_flag'] = 'New Customer'

# %%
# Drop the temporary "order_number" column used for transformation

ords_prods_merged.drop('order_number', axis=1, inplace=True)

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Loyal Customer    32434212
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Group by "loyalty_flag" and calculate basic statistics of product prices

loyalty_stats = ords_prods_merged.groupby('loyalty_flag')['prices'].describe()
print(loyalty_stats)
# Out:
#                      count       mean         std  min  25%  50%   75%  \
# loyalty_flag
# Loyal Customer  32434212.0  11.981144  495.431111  1.0  4.2  7.4  11.3
#
#                     max
# loyalty_flag
# Loyal Customer  99999.0

# %% [markdown]
# ### 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
#
# ##### a. If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# ##### b. If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Calculate mean prices and store them in a variable

mean_price = ords_prods_merged['prices'].mean()

# %%
# Create a new column "spending_flag" based on the mean prices

ords_prods_merged.loc[ords_prods_merged['prices'] >= mean_price, 'spending_flag'] = 'High spender'

# %%
# Create a new column "spending_flag" based on the mean prices

ords_prods_merged.loc[ords_prods_merged['prices'] < mean_price, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     25806292
# High spender     6627920
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# ##### a. If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# ##### b. If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# ##### c. If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.

# %%
# Calculate median days and store it in a variable

median_days = ords_prods_merged['days_since_prior_order'].median()

# %%
# Create a new column "order_frequency_flag" based on the median days
ords_prods_merged.loc[ords_prods_merged['days_since_prior_order'] <= median_days, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Create a new column "order_frequency_flag" based on the median days

ords_prods_merged.loc[ords_prods_merged['days_since_prior_order'] > median_days, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        16872490
# Non-frequent customer    15561722
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# ### 8. Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Save as pickle file format

ords_prods_merged.to_pickle("Prepared Data/prepared_dataframe.pkl")
